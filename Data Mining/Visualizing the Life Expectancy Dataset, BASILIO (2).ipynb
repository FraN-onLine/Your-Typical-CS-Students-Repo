# %% [markdown]
# # Visualizing the Life Expectancy Dataset

# %% [markdown]
# Life expectancy quantifies the average period that a certain individual expects to live.  In this activity, you will explore how happiness and the economic status of a country affect the life expectancy of its countrymen.
#
# Document all parts of your code using the text cell/section in Colab and include a section to discuss your findings.
#
# ## Rubric
# | Criteria                     | Poor | Fair  | Good  | Very Good  |
# |------------------------------|------|------|------|-----------|
# |  1.  **Correctness of the Output**   | No Submission. *(0 Point)*| Less than 50% of the target output was met. *(1 Point)* | At least 50% of the target output was met. *(2 Points)* | All of the target output was met. *(3 Points)* |
# | 2.  **Correctness of the Algorithm** | No Submission *(0 Point)* | The applied algorithm needs major revision. *(1 Point)* | The applied algorithm needs minor revision. *(3 Points)* | The applied algorithm is correctly implemented. *(6 Points)* |
# | 3.  **Documentation** | No Submission. *(0 Point)* | Less than 50% of the code is documented. *(1 Point)* | 70% of the code is documented. *(2 Points)* | 100% of the code is documented. *(3 Points)*

# %%
# do not change this cell/section
# run this section to initialize your dataset

import pandas as pd
import matplotlib.pyplot as plt

# google resource initialization
url = 'https://drive.google.com/file/d/10Bl75VAt2U3XTFoc8hBJbu9tvfvh7BMa/view?usp=sharing'
file_id=url.split('/')[-2]
dwn_url='https://drive.google.com/uc?id=' + file_id

# read the dataset
dataset = pd.read_csv(dwn_url)

dataset.drop(['Country Code', 'Indicator Name','Indicator Code'], inplace = True, axis=1)
dataset.head()
# Out:
#                   Country Name       1960       1961       1962       1963  \
# 0                        Aruba  65.662000  66.074000  66.444000  66.787000
# 1  Africa Eastern and Southern  42.716053  43.166935  43.603990  44.025617
# 2                  Afghanistan  32.446000  32.962000  33.471000  33.971000
# 3   Africa Western and Central  37.205380  37.632546  38.052612  38.463746
# 4                       Angola  37.524000  37.811000  38.113000  38.430000
#
#         1964       1965       1966       1967       1968  ...       2012  \
# 0  67.113000  67.435000  67.762000  68.095000  68.436000  ...  75.299000
# 1  44.432721  44.826919  45.213048  45.594294  45.974059  ...  60.185561
# 2  34.463000  34.948000  35.430000  35.914000  36.403000  ...  62.054000
# 3  38.867073  39.264841  39.662762  40.066408  40.482832  ...  55.138944
# 4  38.760000  39.102000  39.454000  39.813000  40.178000  ...  57.236000
#
#         2013       2014       2015       2016       2017       2018  \
# ...

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# For your first objective, you need to compare and visualize the life expectancy of those countries with the happiest (`Finland`, `Denmark`, `Norway`) and saddest (`South Sudan`, `Central African Republic`, `Afghanistan`) individuals.  Discuss your perception of the figure and whether emotions might affect life expectancy.

# %%
#the 6 countries for analysis
countries = ['Finland', 'Denmark', 'Norway', 'South Sudan', 'Central African Republic', 'Afghanistan']
subset = dataset[dataset['Country Name'].isin(countries)]

#transpose so x and y axises swap 
subset = subset.set_index('Country Name').transpose()

#make year into columns
subset = subset.reset_index().rename(columns={'index': 'Year'})

#convert to numerical data to avoid issues
subset['Year'] = subset['Year'].astype(int)

# line plot is efficient for this scenario
subset.plot.line(x='Year', marker='', figsize=(14, 7))

plt.title('Life Expectancy and Mood')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.grid(True)
plt.xticks(subset['Year'], rotation=45)
plt.legend(title='Country')
plt.tight_layout()
plt.show()

# %%
# A Line graph is used for this activity because and i quote- "Line graphs are most commonly used to plot continuous data.
# Because the points are physically connected via the line, it implies
# a connection between the points that may not make sense for categorical data *(a set of data that is sorted or divided into different
# categories)*. Often, our continuous data is in some unit of time: days,
# months, quarters, or years." - Baculpo, 2025

# and after being able to visualize the data, you can visually see a correlation between life expectancy and happiness
# Happier Countries shows higher life exoectancy
# Sadder Countries shows lower life expectancies

# %% [markdown]
# Your next objective is to compare and visualize the life expectancy of those countries with the best (`Luxembourg`, `Ireland`, `Singapore`) and worst (`Burundi`, `Somalia`, `Mozambique`) economic status in the world.  Also, discuss your perception of the figure and whether the economic status of the country might affect life expectancy.

# %%
#the 6 countries for analysis
countries = ['Luxembourg', 'Ireland', 'Singapore', 'Burundi', 'Somalia', 'Mozambique']
subset = dataset[dataset['Country Name'].isin(countries)]

#transpose so x and y axises swap 
subset = subset.set_index('Country Name').transpose()

#make year into columns
subset = subset.reset_index().rename(columns={'index': 'Year'})

#convert to numerical data to avoid issues
subset['Year'] = subset['Year'].astype(int)

# line plot is efficient for this scenario
subset.plot.line(x='Year', marker='', figsize=(14, 7))

plt.title('Life Expectancy and Economic Status')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.grid(True)
plt.xticks(subset['Year'], rotation=45)
plt.legend(title='Country')
plt.tight_layout()
plt.show()

# %%
# A noticable observation can be seen again in this graph showing more wealthy countries having higher life expectancies, while poorer having
# lower life expectancies, bat di ko minarkdown at nagcomment nalang? ewan,
# the margin gap of the two sets proves as much that a correlation is present
# Higher Economical Status Countries shows higher life exoectancy
# Lower Econ Status Countries shows lower life expectancies

# %% [markdown]
# And finally, compare and visualize the life expectancy of the Philippines to `Finland`, `Luxembourg`, `Burundi`, and `South Sudan`.  Discuss your perception of the figure.

# %%
#the 5 countries for analysis
countries = ['Philippines', 'Finland', 'Luxembourg', 'Burundi', 'South Sudan']
subset = dataset[dataset['Country Name'].isin(countries)]

#transpose so x and y axises swap 
subset = subset.set_index('Country Name').transpose()

#make year into columns
subset = subset.reset_index().rename(columns={'index': 'Year'})

#convert to numerical data to avoid issues
subset['Year'] = subset['Year'].astype(int)

#line plot is efficient for this scenario
subset.plot.line(x='Year', marker='', figsize=(14, 7))

#binabasa mo ba sir?
plt.title('Life Expectancy: Philippines in Comparison')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.grid(True)
plt.xticks(subset['Year'], rotation=45)
plt.legend(title='Country')
plt.tight_layout()
plt.show()

#redundant ba yung code?
#oo naman
#paulit ulit lang yan

# %%
# It's more fun in da Philippines? ata..
# Philippines lies between the upper bounds and the lower bounds of this sample, naturally both of it's economic status and mood
# does lie in between aswell(by deduction as we used the outlier data/min&max of both mood and econ), so can we actually correlate that
# a) life expectancy and happiness has any correlation? we can assume that it has atleast an impact, yes. and 
# b) life expectancy and economic status has any correlation? we can also assume that it has atleast an impact, yes.
# c) Countries who had lower life expectancies before shows a more gradual increase, while the increase becomes more steady as we reach higher expectancies
